# %%
# %run -i plot_statistical_results.py
# %run -i optimization.py 
# %run -i circuito_v5.py
# %run -i create_data.py


learning_rate = 0.01
epochs = 300
batch_size = 16
qubits = 2
kernel_fn = kernel_v5
X = X_train
Y = Y_train

# %% [markdown]
# # 1 Capa

# %%
layers = 1
opt_1Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k5(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="1 Layer")
# Out:
# Layer(s) = 1 ---- Epochs = 5 ---- Train KTA = 0.08961722
# Layer(s) = 1 ---- Epochs = 10 ---- Train KTA = 0.10870682
# Layer(s) = 1 ---- Epochs = 15 ---- Train KTA = 0.12607385
# Layer(s) = 1 ---- Epochs = 20 ---- Train KTA = 0.13663301
# Layer(s) = 1 ---- Epochs = 25 ---- Train KTA = 0.14316289
# Layer(s) = 1 ---- Epochs = 30 ---- Train KTA = 0.14927606
# Layer(s) = 1 ---- Epochs = 35 ---- Train KTA = 0.15090750
# Layer(s) = 1 ---- Epochs = 40 ---- Train KTA = 0.14948258
# Layer(s) = 1 ---- Epochs = 45 ---- Train KTA = 0.14829907
# Layer(s) = 1 ---- Epochs = 50 ---- Train KTA = 0.14880304
# Layer(s) = 1 ---- Epochs = 55 ---- Train KTA = 0.14978842
# Layer(s) = 1 ---- Epochs = 60 ---- Train KTA = 0.15256569
# Layer(s) = 1 ---- Epochs = 65 ---- Train KTA = 0.15550230
# Layer(s) = 1 ---- Epochs = 70 ---- Train KTA = 0.15552969
# Layer(s) = 1 ---- Epochs = 75 ---- Train KTA = 0.15397973
# Layer(s) = 1 ---- Epochs = 80 ---- Train KTA = 0.15385054
# Layer(s) = 1 ---- Epochs = 85 ---- Train KTA = 0.15604191
# Layer(s) = 1 ---- Epochs = 90 ---- Train KTA = 0.15755403
# Layer(s) = 1 ---- Epochs = 95 ---- Train KTA = 0.15865220
# Layer(s) = 1 ---- Epochs = 100 ---- Train KTA = 0.15884392
# Layer(s) = 1 ---- Epochs = 105 ---- Train KTA = 0.15792653
# Layer(s) = 1 ---- Epochs = 110 ---- Train KTA = 0.15819006
# Layer(s) = 1 ---- Epochs = 115 ---- Train KTA = 0.15911967
# Layer(s) = 1 ---- Epochs = 120 ---- Train KTA = 0.15985261
# Layer(s) = 1 ---- Epochs = 125 ---- Train KTA = 0.15970807
# Layer(s) = 1 ---- Epochs = 130 ---- Train KTA = 0.16067787
# Layer(s) = 1 ---- Epochs = 135 ---- Train KTA = 0.16091034
# Layer(s) = 1 ---- Epochs = 140 ---- Train KTA = 0.16109379
# Layer(s) = 1 ---- Epochs = 145 ---- Train KTA = 0.16081455
# Layer(s) = 1 ---- Epochs = 150 ---- Train KTA = 0.16046628
# Layer(s) = 1 ---- Epochs = 155 ---- Train KTA = 0.16044343
# Layer(s) = 1 ---- Epochs = 160 ---- Train KTA = 0.16008724
# Layer(s) = 1 ---- Epochs = 165 ---- Train KTA = 0.15917370
# Layer(s) = 1 ---- Epochs = 170 ---- Train KTA = 0.15822560
# Layer(s) = 1 ---- Epochs = 175 ---- Train KTA = 0.15868725
# Layer(s) = 1 ---- Epochs = 180 ---- Train KTA = 0.15933159
# Layer(s) = 1 ---- Epochs = 185 ---- Train KTA = 0.15932216
# Layer(s) = 1 ---- Epochs = 190 ---- Train KTA = 0.16061640
# Layer(s) = 1 ---- Epochs = 195 ---- Train KTA = 0.16041344
# Layer(s) = 1 ---- Epochs = 200 ---- Train KTA = 0.15881859
# Layer(s) = 1 ---- Epochs = 205 ---- Train KTA = 0.15737405
# Layer(s) = 1 ---- Epochs = 210 ---- Train KTA = 0.15808842
# Layer(s) = 1 ---- Epochs = 215 ---- Train KTA = 0.15809900
# Layer(s) = 1 ---- Epochs = 220 ---- Train KTA = 0.15911947
# Layer(s) = 1 ---- Epochs = 225 ---- Train KTA = 0.15936613
# Layer(s) = 1 ---- Epochs = 230 ---- Train KTA = 0.15943722
# Layer(s) = 1 ---- Epochs = 235 ---- Train KTA = 0.16104405
# Layer(s) = 1 ---- Epochs = 240 ---- Train KTA = 0.16202530
# Layer(s) = 1 ---- Epochs = 245 ---- Train KTA = 0.16163485
# Layer(s) = 1 ---- Epochs = 250 ---- Train KTA = 0.16108194
# Layer(s) = 1 ---- Epochs = 255 ---- Train KTA = 0.16114481
# Layer(s) = 1 ---- Epochs = 260 ---- Train KTA = 0.16088668
# Layer(s) = 1 ---- Epochs = 265 ---- Train KTA = 0.16154186
# Layer(s) = 1 ---- Epochs = 270 ---- Train KTA = 0.16177733
# Layer(s) = 1 ---- Epochs = 275 ---- Train KTA = 0.16069821
# Layer(s) = 1 ---- Epochs = 280 ---- Train KTA = 0.15891930
# Layer(s) = 1 ---- Epochs = 285 ---- Train KTA = 0.16046585
# Layer(s) = 1 ---- Epochs = 290 ---- Train KTA = 0.16200258
# Layer(s) = 1 ---- Epochs = 295 ---- Train KTA = 0.16124323
# Layer(s) = 1 ---- Epochs = 300 ---- Train KTA = 0.16047019

# %%
opt_1Layer
# Out:
# {'params_init': tensor([[[0.8170, 0.1863]],
#
#          [[0.4375, 0.7794]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.4183, -0.3609]],
#
#          [[ 0.7005,  0.6796]]], requires_grad=True),
#  'latest_kta': tensor(0.1605, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 2 Capas

# %%
layers = 2
opt_2Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k5(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="2 Layers")
# Out:
# Layer(s) = 2 ---- Epochs = 5 ---- Train KTA = 0.17480852
# Layer(s) = 2 ---- Epochs = 10 ---- Train KTA = 0.18056302
# Layer(s) = 2 ---- Epochs = 15 ---- Train KTA = 0.18826933
# Layer(s) = 2 ---- Epochs = 20 ---- Train KTA = 0.19628522
# Layer(s) = 2 ---- Epochs = 25 ---- Train KTA = 0.20336957
# Layer(s) = 2 ---- Epochs = 30 ---- Train KTA = 0.20630465
# Layer(s) = 2 ---- Epochs = 35 ---- Train KTA = 0.20759712
# Layer(s) = 2 ---- Epochs = 40 ---- Train KTA = 0.20849957
# Layer(s) = 2 ---- Epochs = 45 ---- Train KTA = 0.20956615
# Layer(s) = 2 ---- Epochs = 50 ---- Train KTA = 0.20976953
# Layer(s) = 2 ---- Epochs = 55 ---- Train KTA = 0.20864567
# Layer(s) = 2 ---- Epochs = 60 ---- Train KTA = 0.20684455
# Layer(s) = 2 ---- Epochs = 65 ---- Train KTA = 0.20687650
# Layer(s) = 2 ---- Epochs = 70 ---- Train KTA = 0.20752154
# Layer(s) = 2 ---- Epochs = 75 ---- Train KTA = 0.20910381
# Layer(s) = 2 ---- Epochs = 80 ---- Train KTA = 0.21053748
# Layer(s) = 2 ---- Epochs = 85 ---- Train KTA = 0.21091282
# Layer(s) = 2 ---- Epochs = 90 ---- Train KTA = 0.21083407
# Layer(s) = 2 ---- Epochs = 95 ---- Train KTA = 0.21057375
# Layer(s) = 2 ---- Epochs = 100 ---- Train KTA = 0.21006319
# Layer(s) = 2 ---- Epochs = 105 ---- Train KTA = 0.20864800
# Layer(s) = 2 ---- Epochs = 110 ---- Train KTA = 0.20748211
# Layer(s) = 2 ---- Epochs = 115 ---- Train KTA = 0.20580806
# Layer(s) = 2 ---- Epochs = 120 ---- Train KTA = 0.20737135
# Layer(s) = 2 ---- Epochs = 125 ---- Train KTA = 0.20834450
# Layer(s) = 2 ---- Epochs = 130 ---- Train KTA = 0.20628597
# Layer(s) = 2 ---- Epochs = 135 ---- Train KTA = 0.20387369
# Layer(s) = 2 ---- Epochs = 140 ---- Train KTA = 0.20359571
# Layer(s) = 2 ---- Epochs = 145 ---- Train KTA = 0.20626895
# Layer(s) = 2 ---- Epochs = 150 ---- Train KTA = 0.20781037
# Layer(s) = 2 ---- Epochs = 155 ---- Train KTA = 0.20974594
# Layer(s) = 2 ---- Epochs = 160 ---- Train KTA = 0.20937741
# Layer(s) = 2 ---- Epochs = 165 ---- Train KTA = 0.20469585
# Layer(s) = 2 ---- Epochs = 170 ---- Train KTA = 0.20420936
# Layer(s) = 2 ---- Epochs = 175 ---- Train KTA = 0.20615542
# Layer(s) = 2 ---- Epochs = 180 ---- Train KTA = 0.20730212
# Layer(s) = 2 ---- Epochs = 185 ---- Train KTA = 0.20871159
# Layer(s) = 2 ---- Epochs = 190 ---- Train KTA = 0.20959722
# Layer(s) = 2 ---- Epochs = 195 ---- Train KTA = 0.20916291
# Layer(s) = 2 ---- Epochs = 200 ---- Train KTA = 0.20784371
# Layer(s) = 2 ---- Epochs = 205 ---- Train KTA = 0.20753630
# Layer(s) = 2 ---- Epochs = 210 ---- Train KTA = 0.20988999
# Layer(s) = 2 ---- Epochs = 215 ---- Train KTA = 0.21071936
# Layer(s) = 2 ---- Epochs = 220 ---- Train KTA = 0.20998579
# Layer(s) = 2 ---- Epochs = 225 ---- Train KTA = 0.20876467
# Layer(s) = 2 ---- Epochs = 230 ---- Train KTA = 0.20765530
# Layer(s) = 2 ---- Epochs = 235 ---- Train KTA = 0.20745873
# Layer(s) = 2 ---- Epochs = 240 ---- Train KTA = 0.20871238
# Layer(s) = 2 ---- Epochs = 245 ---- Train KTA = 0.20934844
# Layer(s) = 2 ---- Epochs = 250 ---- Train KTA = 0.20985931
# Layer(s) = 2 ---- Epochs = 255 ---- Train KTA = 0.20986225
# Layer(s) = 2 ---- Epochs = 260 ---- Train KTA = 0.20849723
# Layer(s) = 2 ---- Epochs = 265 ---- Train KTA = 0.20588972
# Layer(s) = 2 ---- Epochs = 270 ---- Train KTA = 0.20315123
# Layer(s) = 2 ---- Epochs = 275 ---- Train KTA = 0.20354323
# Layer(s) = 2 ---- Epochs = 280 ---- Train KTA = 0.20703584
# Layer(s) = 2 ---- Epochs = 285 ---- Train KTA = 0.20975305
# Layer(s) = 2 ---- Epochs = 290 ---- Train KTA = 0.21017592
# Layer(s) = 2 ---- Epochs = 295 ---- Train KTA = 0.20940228
# Layer(s) = 2 ---- Epochs = 300 ---- Train KTA = 0.20866524

# %%
opt_2Layer
# Out:
# {'params_init': tensor([[[0.7420, 0.6581],
#           [0.5647, 0.2346]],
#
#          [[0.6370, 0.0982],
#           [0.0037, 0.6306]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.2439,  1.0090],
#           [ 0.9156,  0.4884]],
#
#          [[ 0.4938,  0.3049],
#           [-0.0111,  0.7004]]], requires_grad=True),
#  'latest_kta': tensor(0.2087, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 3 Capas

# %%
layers = 3
opt_3Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k5(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="3 Layers")
# Out:
# Layer(s) = 3 ---- Epochs = 5 ---- Train KTA = 0.18432358
# Layer(s) = 3 ---- Epochs = 10 ---- Train KTA = 0.20119591
# Layer(s) = 3 ---- Epochs = 15 ---- Train KTA = 0.21654214
# Layer(s) = 3 ---- Epochs = 20 ---- Train KTA = 0.22916743
# Layer(s) = 3 ---- Epochs = 25 ---- Train KTA = 0.24365845
# Layer(s) = 3 ---- Epochs = 30 ---- Train KTA = 0.26374993
# Layer(s) = 3 ---- Epochs = 35 ---- Train KTA = 0.28678620
# Layer(s) = 3 ---- Epochs = 40 ---- Train KTA = 0.29852313
# Layer(s) = 3 ---- Epochs = 45 ---- Train KTA = 0.29775336
# Layer(s) = 3 ---- Epochs = 50 ---- Train KTA = 0.29458952
# Layer(s) = 3 ---- Epochs = 55 ---- Train KTA = 0.30222899
# Layer(s) = 3 ---- Epochs = 60 ---- Train KTA = 0.30527070
# Layer(s) = 3 ---- Epochs = 65 ---- Train KTA = 0.30587202
# Layer(s) = 3 ---- Epochs = 70 ---- Train KTA = 0.30546993
# Layer(s) = 3 ---- Epochs = 75 ---- Train KTA = 0.30649966
# Layer(s) = 3 ---- Epochs = 80 ---- Train KTA = 0.30788225
# Layer(s) = 3 ---- Epochs = 85 ---- Train KTA = 0.31072298
# Layer(s) = 3 ---- Epochs = 90 ---- Train KTA = 0.31305584
# Layer(s) = 3 ---- Epochs = 95 ---- Train KTA = 0.31520057
# Layer(s) = 3 ---- Epochs = 100 ---- Train KTA = 0.31592321
# Layer(s) = 3 ---- Epochs = 105 ---- Train KTA = 0.31764489
# Layer(s) = 3 ---- Epochs = 110 ---- Train KTA = 0.32004693
# Layer(s) = 3 ---- Epochs = 115 ---- Train KTA = 0.32292455
# Layer(s) = 3 ---- Epochs = 120 ---- Train KTA = 0.32344127
# Layer(s) = 3 ---- Epochs = 125 ---- Train KTA = 0.32144225
# Layer(s) = 3 ---- Epochs = 130 ---- Train KTA = 0.32255948
# Layer(s) = 3 ---- Epochs = 135 ---- Train KTA = 0.32365024
# Layer(s) = 3 ---- Epochs = 140 ---- Train KTA = 0.32815757
# Layer(s) = 3 ---- Epochs = 145 ---- Train KTA = 0.32993647
# Layer(s) = 3 ---- Epochs = 150 ---- Train KTA = 0.33089259
# Layer(s) = 3 ---- Epochs = 155 ---- Train KTA = 0.34160623
# Layer(s) = 3 ---- Epochs = 160 ---- Train KTA = 0.35199803
# Layer(s) = 3 ---- Epochs = 165 ---- Train KTA = 0.35972947
# Layer(s) = 3 ---- Epochs = 170 ---- Train KTA = 0.36505672
# Layer(s) = 3 ---- Epochs = 175 ---- Train KTA = 0.36616170
# Layer(s) = 3 ---- Epochs = 180 ---- Train KTA = 0.36712110
# Layer(s) = 3 ---- Epochs = 185 ---- Train KTA = 0.36885747
# Layer(s) = 3 ---- Epochs = 190 ---- Train KTA = 0.36966518
# Layer(s) = 3 ---- Epochs = 195 ---- Train KTA = 0.36948875
# Layer(s) = 3 ---- Epochs = 200 ---- Train KTA = 0.36879200
# Layer(s) = 3 ---- Epochs = 205 ---- Train KTA = 0.36595094
# Layer(s) = 3 ---- Epochs = 210 ---- Train KTA = 0.36333126
# Layer(s) = 3 ---- Epochs = 215 ---- Train KTA = 0.36235234
# Layer(s) = 3 ---- Epochs = 220 ---- Train KTA = 0.36331841
# Layer(s) = 3 ---- Epochs = 225 ---- Train KTA = 0.36773348
# Layer(s) = 3 ---- Epochs = 230 ---- Train KTA = 0.36934680
# Layer(s) = 3 ---- Epochs = 235 ---- Train KTA = 0.36922997
# Layer(s) = 3 ---- Epochs = 240 ---- Train KTA = 0.36877251
# Layer(s) = 3 ---- Epochs = 245 ---- Train KTA = 0.36858013
# Layer(s) = 3 ---- Epochs = 250 ---- Train KTA = 0.36631903
# Layer(s) = 3 ---- Epochs = 255 ---- Train KTA = 0.36683577
# Layer(s) = 3 ---- Epochs = 260 ---- Train KTA = 0.36897868
# Layer(s) = 3 ---- Epochs = 265 ---- Train KTA = 0.36812720
# Layer(s) = 3 ---- Epochs = 270 ---- Train KTA = 0.36663234
# Layer(s) = 3 ---- Epochs = 275 ---- Train KTA = 0.36245283
# Layer(s) = 3 ---- Epochs = 280 ---- Train KTA = 0.35999921
# Layer(s) = 3 ---- Epochs = 285 ---- Train KTA = 0.36459315
# Layer(s) = 3 ---- Epochs = 290 ---- Train KTA = 0.36680180
# Layer(s) = 3 ---- Epochs = 295 ---- Train KTA = 0.36596137
# Layer(s) = 3 ---- Epochs = 300 ---- Train KTA = 0.36522618

# %%
opt_3Layer
# Out:
# {'params_init': tensor([[[4.3533e-01, 2.8574e-01],
#           [1.4498e-01, 2.8956e-01],
#           [6.7466e-01, 9.4642e-01]],
#
#          [[7.8624e-04, 7.1583e-01],
#           [9.8206e-01, 8.6098e-02],
#           [6.1835e-01, 8.2152e-02]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.8542,  0.5547],
#           [ 0.4140, -0.5639],
#           [-0.1788,  1.3653]],
#
#          [[ 0.1882,  0.8583],
#           [ 0.9621,  0.1333],
#           [ 0.1351,  0.1645]]], requires_grad=True),
#  'latest_kta': tensor(0.3652, grad_fn=<DivBackward0>)}
