# %%
# %run -i plot_statistical_results.py
# %run -i multiclass_clf.py 
# %run -i circuito_v6.py
# %run -i create_data.py
from pennylane import numpy as np

learning_rate = 0.01
epochs = 300
batch_size = 16
qubits = 2
kernel_fn = kernel_v6
X = X_train
Y = Y_train

# %% [markdown]
# # 1 Capa

# %%
layers = 1
opt_1Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k6(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="1 Layer")
# Out:
# Layer(s) = 1 ---- Epochs = 5 ---- Train KTA = 0.03506089
# Layer(s) = 1 ---- Epochs = 10 ---- Train KTA = 0.04448235
# Layer(s) = 1 ---- Epochs = 15 ---- Train KTA = 0.05299097
# Layer(s) = 1 ---- Epochs = 20 ---- Train KTA = 0.06032313
# Layer(s) = 1 ---- Epochs = 25 ---- Train KTA = 0.06524443
# Layer(s) = 1 ---- Epochs = 30 ---- Train KTA = 0.06810607
# Layer(s) = 1 ---- Epochs = 35 ---- Train KTA = 0.06875210
# Layer(s) = 1 ---- Epochs = 40 ---- Train KTA = 0.06864085
# Layer(s) = 1 ---- Epochs = 45 ---- Train KTA = 0.06866638
# Layer(s) = 1 ---- Epochs = 50 ---- Train KTA = 0.06850794
# Layer(s) = 1 ---- Epochs = 55 ---- Train KTA = 0.06820648
# Layer(s) = 1 ---- Epochs = 60 ---- Train KTA = 0.06734801
# Layer(s) = 1 ---- Epochs = 65 ---- Train KTA = 0.06746969
# Layer(s) = 1 ---- Epochs = 70 ---- Train KTA = 0.06726313
# Layer(s) = 1 ---- Epochs = 75 ---- Train KTA = 0.06656922
# Layer(s) = 1 ---- Epochs = 80 ---- Train KTA = 0.06551068
# Layer(s) = 1 ---- Epochs = 85 ---- Train KTA = 0.06439383
# Layer(s) = 1 ---- Epochs = 90 ---- Train KTA = 0.06450548
# Layer(s) = 1 ---- Epochs = 95 ---- Train KTA = 0.06466852
# Layer(s) = 1 ---- Epochs = 100 ---- Train KTA = 0.06525905
# Layer(s) = 1 ---- Epochs = 105 ---- Train KTA = 0.06633845
# Layer(s) = 1 ---- Epochs = 110 ---- Train KTA = 0.06861471
# Layer(s) = 1 ---- Epochs = 115 ---- Train KTA = 0.07235067
# Layer(s) = 1 ---- Epochs = 120 ---- Train KTA = 0.07637544
# Layer(s) = 1 ---- Epochs = 125 ---- Train KTA = 0.08028700
# Layer(s) = 1 ---- Epochs = 130 ---- Train KTA = 0.08566992
# Layer(s) = 1 ---- Epochs = 135 ---- Train KTA = 0.09345624
# Layer(s) = 1 ---- Epochs = 140 ---- Train KTA = 0.10120665
# Layer(s) = 1 ---- Epochs = 145 ---- Train KTA = 0.11123020
# Layer(s) = 1 ---- Epochs = 150 ---- Train KTA = 0.12224324
# Layer(s) = 1 ---- Epochs = 155 ---- Train KTA = 0.13447730
# Layer(s) = 1 ---- Epochs = 160 ---- Train KTA = 0.14229284
# Layer(s) = 1 ---- Epochs = 165 ---- Train KTA = 0.14646052
# Layer(s) = 1 ---- Epochs = 170 ---- Train KTA = 0.14978610
# Layer(s) = 1 ---- Epochs = 175 ---- Train KTA = 0.15223216
# Layer(s) = 1 ---- Epochs = 180 ---- Train KTA = 0.15385719
# Layer(s) = 1 ---- Epochs = 185 ---- Train KTA = 0.15489635
# Layer(s) = 1 ---- Epochs = 190 ---- Train KTA = 0.15425085
# Layer(s) = 1 ---- Epochs = 195 ---- Train KTA = 0.15348062
# Layer(s) = 1 ---- Epochs = 200 ---- Train KTA = 0.15299712
# Layer(s) = 1 ---- Epochs = 205 ---- Train KTA = 0.15150434
# Layer(s) = 1 ---- Epochs = 210 ---- Train KTA = 0.15062399
# Layer(s) = 1 ---- Epochs = 215 ---- Train KTA = 0.15130201
# Layer(s) = 1 ---- Epochs = 220 ---- Train KTA = 0.15492573
# Layer(s) = 1 ---- Epochs = 225 ---- Train KTA = 0.15705548
# Layer(s) = 1 ---- Epochs = 230 ---- Train KTA = 0.15811515
# Layer(s) = 1 ---- Epochs = 235 ---- Train KTA = 0.15924054
# Layer(s) = 1 ---- Epochs = 240 ---- Train KTA = 0.16067220
# Layer(s) = 1 ---- Epochs = 245 ---- Train KTA = 0.16092913
# Layer(s) = 1 ---- Epochs = 250 ---- Train KTA = 0.16144863
# Layer(s) = 1 ---- Epochs = 255 ---- Train KTA = 0.16162823
# Layer(s) = 1 ---- Epochs = 260 ---- Train KTA = 0.16161729
# Layer(s) = 1 ---- Epochs = 265 ---- Train KTA = 0.16159073
# Layer(s) = 1 ---- Epochs = 270 ---- Train KTA = 0.16164231
# Layer(s) = 1 ---- Epochs = 275 ---- Train KTA = 0.16170016
# Layer(s) = 1 ---- Epochs = 280 ---- Train KTA = 0.16163012
# Layer(s) = 1 ---- Epochs = 285 ---- Train KTA = 0.16119471
# Layer(s) = 1 ---- Epochs = 290 ---- Train KTA = 0.16108145
# Layer(s) = 1 ---- Epochs = 295 ---- Train KTA = 0.16068636
# Layer(s) = 1 ---- Epochs = 300 ---- Train KTA = 0.15983339

# %%
opt_1Layer
# Out:
# {'params_init': tensor([[[0.2304, 0.0463]],
#
#          [[0.9507, 0.1554]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[0.7946, 0.7736]],
#
#          [[0.6614, 0.6806]]], requires_grad=True),
#  'latest_kta': tensor(0.1598, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 2 Capas

# %%
layers = 2
opt_2Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k6(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="2 Layers")
# Out:
# Layer(s) = 2 ---- Epochs = 5 ---- Train KTA = 0.18587179
# Layer(s) = 2 ---- Epochs = 10 ---- Train KTA = 0.24155566
# Layer(s) = 2 ---- Epochs = 15 ---- Train KTA = 0.27444243
# Layer(s) = 2 ---- Epochs = 20 ---- Train KTA = 0.28253555
# Layer(s) = 2 ---- Epochs = 25 ---- Train KTA = 0.28276247
# Layer(s) = 2 ---- Epochs = 30 ---- Train KTA = 0.28715712
# Layer(s) = 2 ---- Epochs = 35 ---- Train KTA = 0.29506785
# Layer(s) = 2 ---- Epochs = 40 ---- Train KTA = 0.29727778
# Layer(s) = 2 ---- Epochs = 45 ---- Train KTA = 0.29599652
# Layer(s) = 2 ---- Epochs = 50 ---- Train KTA = 0.29712677
# Layer(s) = 2 ---- Epochs = 55 ---- Train KTA = 0.29967412
# Layer(s) = 2 ---- Epochs = 60 ---- Train KTA = 0.30303976
# Layer(s) = 2 ---- Epochs = 65 ---- Train KTA = 0.30506068
# Layer(s) = 2 ---- Epochs = 70 ---- Train KTA = 0.30595821
# Layer(s) = 2 ---- Epochs = 75 ---- Train KTA = 0.30726105
# Layer(s) = 2 ---- Epochs = 80 ---- Train KTA = 0.30658507
# Layer(s) = 2 ---- Epochs = 85 ---- Train KTA = 0.30584025
# Layer(s) = 2 ---- Epochs = 90 ---- Train KTA = 0.30816701
# Layer(s) = 2 ---- Epochs = 95 ---- Train KTA = 0.30920359
# Layer(s) = 2 ---- Epochs = 100 ---- Train KTA = 0.30897900
# Layer(s) = 2 ---- Epochs = 105 ---- Train KTA = 0.30807954
# Layer(s) = 2 ---- Epochs = 110 ---- Train KTA = 0.30686831
# Layer(s) = 2 ---- Epochs = 115 ---- Train KTA = 0.30799893
# Layer(s) = 2 ---- Epochs = 120 ---- Train KTA = 0.31101972
# Layer(s) = 2 ---- Epochs = 125 ---- Train KTA = 0.31196260
# Layer(s) = 2 ---- Epochs = 130 ---- Train KTA = 0.31255439
# Layer(s) = 2 ---- Epochs = 135 ---- Train KTA = 0.31301934
# Layer(s) = 2 ---- Epochs = 140 ---- Train KTA = 0.31312782
# Layer(s) = 2 ---- Epochs = 145 ---- Train KTA = 0.31330028
# Layer(s) = 2 ---- Epochs = 150 ---- Train KTA = 0.31285807
# Layer(s) = 2 ---- Epochs = 155 ---- Train KTA = 0.31086776
# Layer(s) = 2 ---- Epochs = 160 ---- Train KTA = 0.31118935
# Layer(s) = 2 ---- Epochs = 165 ---- Train KTA = 0.31247887
# Layer(s) = 2 ---- Epochs = 170 ---- Train KTA = 0.31341189
# Layer(s) = 2 ---- Epochs = 175 ---- Train KTA = 0.31369588
# Layer(s) = 2 ---- Epochs = 180 ---- Train KTA = 0.31350482
# Layer(s) = 2 ---- Epochs = 185 ---- Train KTA = 0.31374449
# Layer(s) = 2 ---- Epochs = 190 ---- Train KTA = 0.31284666
# Layer(s) = 2 ---- Epochs = 195 ---- Train KTA = 0.31088179
# Layer(s) = 2 ---- Epochs = 200 ---- Train KTA = 0.31011730
# Layer(s) = 2 ---- Epochs = 205 ---- Train KTA = 0.31120086
# Layer(s) = 2 ---- Epochs = 210 ---- Train KTA = 0.31249127
# Layer(s) = 2 ---- Epochs = 215 ---- Train KTA = 0.31295308
# Layer(s) = 2 ---- Epochs = 220 ---- Train KTA = 0.31264639
# Layer(s) = 2 ---- Epochs = 225 ---- Train KTA = 0.30984947
# Layer(s) = 2 ---- Epochs = 230 ---- Train KTA = 0.30951071
# Layer(s) = 2 ---- Epochs = 235 ---- Train KTA = 0.31083354
# Layer(s) = 2 ---- Epochs = 240 ---- Train KTA = 0.31162274
# Layer(s) = 2 ---- Epochs = 245 ---- Train KTA = 0.31249878
# Layer(s) = 2 ---- Epochs = 250 ---- Train KTA = 0.31306237
# Layer(s) = 2 ---- Epochs = 255 ---- Train KTA = 0.31298333
# Layer(s) = 2 ---- Epochs = 260 ---- Train KTA = 0.31299698
# Layer(s) = 2 ---- Epochs = 265 ---- Train KTA = 0.30941662
# Layer(s) = 2 ---- Epochs = 270 ---- Train KTA = 0.30739981
# Layer(s) = 2 ---- Epochs = 275 ---- Train KTA = 0.31013057
# Layer(s) = 2 ---- Epochs = 280 ---- Train KTA = 0.31127095
# Layer(s) = 2 ---- Epochs = 285 ---- Train KTA = 0.31212935
# Layer(s) = 2 ---- Epochs = 290 ---- Train KTA = 0.31301364
# Layer(s) = 2 ---- Epochs = 295 ---- Train KTA = 0.31340531
# Layer(s) = 2 ---- Epochs = 300 ---- Train KTA = 0.31300479

# %%
opt_2Layer
# Out:
# {'params_init': tensor([[[0.6891, 0.1179],
#           [0.0349, 0.5361]],
#
#          [[0.4701, 0.2472],
#           [0.9872, 0.2809]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[1.0969, 0.2661],
#           [0.2629, 0.2750]],
#
#          [[0.5704, 0.6149],
#           [1.1460, 0.5751]]], requires_grad=True),
#  'latest_kta': tensor(0.3130, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 3 Capas

# %%
layers = 3
opt_3Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k6(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="3 Layers")
# Out:
# Layer(s) = 3 ---- Epochs = 5 ---- Train KTA = 0.10536373
# Layer(s) = 3 ---- Epochs = 10 ---- Train KTA = 0.12427281
# Layer(s) = 3 ---- Epochs = 15 ---- Train KTA = 0.14563642
# Layer(s) = 3 ---- Epochs = 20 ---- Train KTA = 0.17376663
# Layer(s) = 3 ---- Epochs = 25 ---- Train KTA = 0.20440677
# Layer(s) = 3 ---- Epochs = 30 ---- Train KTA = 0.22719839
# Layer(s) = 3 ---- Epochs = 35 ---- Train KTA = 0.24548833
# Layer(s) = 3 ---- Epochs = 40 ---- Train KTA = 0.26481327
# Layer(s) = 3 ---- Epochs = 45 ---- Train KTA = 0.27928865
# Layer(s) = 3 ---- Epochs = 50 ---- Train KTA = 0.28527504
# Layer(s) = 3 ---- Epochs = 55 ---- Train KTA = 0.29008472
# Layer(s) = 3 ---- Epochs = 60 ---- Train KTA = 0.29500738
# Layer(s) = 3 ---- Epochs = 65 ---- Train KTA = 0.29917043
# Layer(s) = 3 ---- Epochs = 70 ---- Train KTA = 0.29711929
# Layer(s) = 3 ---- Epochs = 75 ---- Train KTA = 0.29713112
# Layer(s) = 3 ---- Epochs = 80 ---- Train KTA = 0.30017576
# Layer(s) = 3 ---- Epochs = 85 ---- Train KTA = 0.30476427
# Layer(s) = 3 ---- Epochs = 90 ---- Train KTA = 0.30686390
# Layer(s) = 3 ---- Epochs = 95 ---- Train KTA = 0.30757180
# Layer(s) = 3 ---- Epochs = 100 ---- Train KTA = 0.30847675
# Layer(s) = 3 ---- Epochs = 105 ---- Train KTA = 0.30915320
# Layer(s) = 3 ---- Epochs = 110 ---- Train KTA = 0.30942678
# Layer(s) = 3 ---- Epochs = 115 ---- Train KTA = 0.30973464
# Layer(s) = 3 ---- Epochs = 120 ---- Train KTA = 0.30627134
# Layer(s) = 3 ---- Epochs = 125 ---- Train KTA = 0.30404478
# Layer(s) = 3 ---- Epochs = 130 ---- Train KTA = 0.29903585
# Layer(s) = 3 ---- Epochs = 135 ---- Train KTA = 0.29637012
# Layer(s) = 3 ---- Epochs = 140 ---- Train KTA = 0.29801702
# Layer(s) = 3 ---- Epochs = 145 ---- Train KTA = 0.30444863
# Layer(s) = 3 ---- Epochs = 150 ---- Train KTA = 0.30965886
# Layer(s) = 3 ---- Epochs = 155 ---- Train KTA = 0.30994886
# Layer(s) = 3 ---- Epochs = 160 ---- Train KTA = 0.30998716
# Layer(s) = 3 ---- Epochs = 165 ---- Train KTA = 0.30845219
# Layer(s) = 3 ---- Epochs = 170 ---- Train KTA = 0.30665153
# Layer(s) = 3 ---- Epochs = 175 ---- Train KTA = 0.30669427
# Layer(s) = 3 ---- Epochs = 180 ---- Train KTA = 0.31089014
# Layer(s) = 3 ---- Epochs = 185 ---- Train KTA = 0.31258753
# Layer(s) = 3 ---- Epochs = 190 ---- Train KTA = 0.31128907
# Layer(s) = 3 ---- Epochs = 195 ---- Train KTA = 0.31044781
# Layer(s) = 3 ---- Epochs = 200 ---- Train KTA = 0.31122860
# Layer(s) = 3 ---- Epochs = 205 ---- Train KTA = 0.31083995
# Layer(s) = 3 ---- Epochs = 210 ---- Train KTA = 0.31189194
# Layer(s) = 3 ---- Epochs = 215 ---- Train KTA = 0.31222588
# Layer(s) = 3 ---- Epochs = 220 ---- Train KTA = 0.31292894
# Layer(s) = 3 ---- Epochs = 225 ---- Train KTA = 0.31281629
# Layer(s) = 3 ---- Epochs = 230 ---- Train KTA = 0.31207082
# Layer(s) = 3 ---- Epochs = 235 ---- Train KTA = 0.30879959
# Layer(s) = 3 ---- Epochs = 240 ---- Train KTA = 0.31104001
# Layer(s) = 3 ---- Epochs = 245 ---- Train KTA = 0.31282556
# Layer(s) = 3 ---- Epochs = 250 ---- Train KTA = 0.31280124
# Layer(s) = 3 ---- Epochs = 255 ---- Train KTA = 0.31117225
# Layer(s) = 3 ---- Epochs = 260 ---- Train KTA = 0.30979949
# Layer(s) = 3 ---- Epochs = 265 ---- Train KTA = 0.30868667
# Layer(s) = 3 ---- Epochs = 270 ---- Train KTA = 0.31000298
# Layer(s) = 3 ---- Epochs = 275 ---- Train KTA = 0.30948630
# Layer(s) = 3 ---- Epochs = 280 ---- Train KTA = 0.31072527
# Layer(s) = 3 ---- Epochs = 285 ---- Train KTA = 0.31116188
# Layer(s) = 3 ---- Epochs = 290 ---- Train KTA = 0.31153139
# Layer(s) = 3 ---- Epochs = 295 ---- Train KTA = 0.31256542
# Layer(s) = 3 ---- Epochs = 300 ---- Train KTA = 0.31250206

# %%
opt_3Layer
# Out:
# {'params_init': tensor([[[0.9591, 0.1970],
#           [0.9230, 0.5824],
#           [0.8952, 0.8233]],
#
#          [[0.7865, 0.0972],
#           [0.6272, 0.6699],
#           [0.8039, 0.3662]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.7590, -0.2787],
#           [ 1.2605,  0.2843],
#           [ 0.2843,  0.5935]],
#
#          [[ 0.9339, -0.1434],
#           [ 0.3980,  0.8959],
#           [ 1.4279,  0.3930]]], requires_grad=True),
#  'latest_kta': tensor(0.3125, grad_fn=<DivBackward0>)}
