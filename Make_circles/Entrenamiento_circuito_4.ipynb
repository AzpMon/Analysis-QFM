# %%
# %run -i plot_statistical_results.py
# %run -i optimization.py 
# %run -i circuito_v4.py
# %run -i create_data.py


learning_rate = 0.01
epochs = 350
batch_size = 16
qubits = 2
kernel_fn = kernel_v4
X = X_train
Y = Y_train

# %% [markdown]
# # 1 Capa

# %%
layers = 1
opt_1Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k4(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="1 Layer")
# Out:
# Layer(s) = 1 ---- Epochs = 5 ---- Train KTA = 0.02067277
# Layer(s) = 1 ---- Epochs = 10 ---- Train KTA = 0.02251577
# Layer(s) = 1 ---- Epochs = 15 ---- Train KTA = 0.02457128
# Layer(s) = 1 ---- Epochs = 20 ---- Train KTA = 0.02641110
# Layer(s) = 1 ---- Epochs = 25 ---- Train KTA = 0.02815781
# Layer(s) = 1 ---- Epochs = 30 ---- Train KTA = 0.02969224
# Layer(s) = 1 ---- Epochs = 35 ---- Train KTA = 0.03058591
# Layer(s) = 1 ---- Epochs = 40 ---- Train KTA = 0.03059981
# Layer(s) = 1 ---- Epochs = 45 ---- Train KTA = 0.03032930
# Layer(s) = 1 ---- Epochs = 50 ---- Train KTA = 0.02951993
# Layer(s) = 1 ---- Epochs = 55 ---- Train KTA = 0.02901390
# Layer(s) = 1 ---- Epochs = 60 ---- Train KTA = 0.02875626
# Layer(s) = 1 ---- Epochs = 65 ---- Train KTA = 0.02873731
# Layer(s) = 1 ---- Epochs = 70 ---- Train KTA = 0.02864717
# Layer(s) = 1 ---- Epochs = 75 ---- Train KTA = 0.02796354
# Layer(s) = 1 ---- Epochs = 80 ---- Train KTA = 0.02745199
# ...

# %%
opt_1Layer
# Out:
# {'params_init': tensor([[[0.4500, 0.3202]],
#
#          [[0.4550, 0.4648]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.0125, -0.0065]],
#
#          [[ 0.8011,  0.6983]]], requires_grad=True),
#  'latest_kta': tensor(0.0271, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 2 Capas

# %%
layers = 2
opt_2Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k4(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="2 Layers")
# Out:
# Layer(s) = 2 ---- Epochs = 5 ---- Train KTA = 0.04657134
# Layer(s) = 2 ---- Epochs = 10 ---- Train KTA = 0.05236497
# Layer(s) = 2 ---- Epochs = 15 ---- Train KTA = 0.05685430
# Layer(s) = 2 ---- Epochs = 20 ---- Train KTA = 0.06177928
# Layer(s) = 2 ---- Epochs = 25 ---- Train KTA = 0.06606562
# Layer(s) = 2 ---- Epochs = 30 ---- Train KTA = 0.06912987
# Layer(s) = 2 ---- Epochs = 35 ---- Train KTA = 0.07228789
# Layer(s) = 2 ---- Epochs = 40 ---- Train KTA = 0.07560897
# Layer(s) = 2 ---- Epochs = 45 ---- Train KTA = 0.07835532
# Layer(s) = 2 ---- Epochs = 50 ---- Train KTA = 0.08108798
# Layer(s) = 2 ---- Epochs = 55 ---- Train KTA = 0.08334941
# Layer(s) = 2 ---- Epochs = 60 ---- Train KTA = 0.08603051
# Layer(s) = 2 ---- Epochs = 65 ---- Train KTA = 0.08788970
# Layer(s) = 2 ---- Epochs = 70 ---- Train KTA = 0.08977515
# Layer(s) = 2 ---- Epochs = 75 ---- Train KTA = 0.09146446
# Layer(s) = 2 ---- Epochs = 80 ---- Train KTA = 0.09265034
# ...

# %%
opt_2Layer
# Out:
# {'params_init': tensor([[[0.7623, 0.7448],
#           [0.7158, 0.7154]],
#
#          [[0.9716, 0.7260],
#           [0.1758, 0.2746]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[0.5869, 1.2154],
#           [0.4606, 1.9823]],
#
#          [[0.3906, 0.0915],
#           [0.4860, 0.8554]]], requires_grad=True),
#  'latest_kta': tensor(0.2599, grad_fn=<DivBackward0>)}

# %% [markdown]
# # 3 Capas

# %%
layers = 3
opt_3Layer=optimization(learning_rate, epochs, batch_size,qubits,layers,kernel_fn,
                        params=create_params_k4(qubits=qubits, layers=layers),
                        X=X_train,Y=Y_train, plot_kta = True, title="3 Layers")
# Out:
# Layer(s) = 3 ---- Epochs = 5 ---- Train KTA = 0.08705635
# Layer(s) = 3 ---- Epochs = 10 ---- Train KTA = 0.09929328
# Layer(s) = 3 ---- Epochs = 15 ---- Train KTA = 0.10224968
# Layer(s) = 3 ---- Epochs = 20 ---- Train KTA = 0.10987708
# Layer(s) = 3 ---- Epochs = 25 ---- Train KTA = 0.11389835
# Layer(s) = 3 ---- Epochs = 30 ---- Train KTA = 0.11198118
# Layer(s) = 3 ---- Epochs = 35 ---- Train KTA = 0.11285220
# Layer(s) = 3 ---- Epochs = 40 ---- Train KTA = 0.11489133
# Layer(s) = 3 ---- Epochs = 45 ---- Train KTA = 0.11688247
# Layer(s) = 3 ---- Epochs = 50 ---- Train KTA = 0.11939136
# Layer(s) = 3 ---- Epochs = 55 ---- Train KTA = 0.12165891
# Layer(s) = 3 ---- Epochs = 60 ---- Train KTA = 0.12155816
# Layer(s) = 3 ---- Epochs = 65 ---- Train KTA = 0.12150662
# Layer(s) = 3 ---- Epochs = 70 ---- Train KTA = 0.12294424
# Layer(s) = 3 ---- Epochs = 75 ---- Train KTA = 0.12463214
# Layer(s) = 3 ---- Epochs = 80 ---- Train KTA = 0.12474670
# ...

# %%
opt_3Layer
# Out:
# {'params_init': tensor([[[0.4788, 0.5958],
#           [0.2926, 0.1147],
#           [0.0041, 0.3066]],
#
#          [[0.5196, 0.6883],
#           [0.7283, 0.2278],
#           [0.8123, 0.9171]]], grad_fn=<CloneBackward0>),
#  'params_opt': tensor([[[ 0.2990,  0.1918],
#           [ 0.5134, -0.0271],
#           [-0.1821,  0.3298]],
#
#          [[ 0.6297,  0.7417],
#           [ 0.9529,  0.2691],
#           [ 1.1297,  0.9318]]], requires_grad=True),
#  'latest_kta': tensor(0.1440, grad_fn=<DivBackward0>)}
